# %%
import json
import pandas as pd
import os
import glob

# Opening JSON file
data_location = os.path.join('data', '*.json')
print(data_location)

# output files
data_out = os.path.join('data', '*.csv')
print(data_out)

filenames = glob.glob(data_location)
print(filenames)

df_total = pd.DataFrame()
# Out:
# data/*.json
# data/*.csv
# ['data/20.json', 'data/36.json', 'data/16.json', 'data/6.json', 'data/7.json', 'data/17.json', 'data/40.json', 'data/37.json', 'data/21.json', 'data/10.json', 'data/0.json', 'data/26.json', 'data/30.json', 'data/31.json', 'data/27.json', 'data/1.json', 'data/11.json', 'data/2.json', 'data/28.json', 'data/12.json', 'data/32.json', 'data/24.json', 'data/25.json', 'data/33.json', 'data/13.json', 'data/29.json', 'data/3.json', 'data/34.json', 'data/8.json', 'data/22.json', 'data/18.json', 'data/38.json', 'data/4.json', 'data/14.json', 'data/15.json', 'data/5.json', 'data/39.json', 'data/19.json', 'data/23.json', 'data/9.json', 'data/35.json']

# %%
for f in filenames:
    # modify the data structure
    datafile = open(f)
    data = json.load(datafile)
    df = pd.DataFrame(data)
    # expand information of the original post being reposted: normalize the column of dictionaries
    df_repost = pd.json_normalize(df.repost)
    # add prefix to avoid overlap of column names
    df_repost = df_repost.add_prefix('Repost_')
    #  and join the repost df with main df
    df = df.join(df_repost)
    # drop original repost column
    df.drop(columns=['repost'], inplace=True)
    # randomly sample 1/100 of the dataset
    df_s = df.sample(n=1000)
    df_total = pd.concat([df_total, df_s])

# %%
df_total
# Out:
#                  From                                            content  \
# 49974    微博 weibo.com  #最新疫情通报# 【2月16日，汉中新增4例确诊病例，累计确诊25例】截至2月16日9时，陕...
# 40536    微博 weibo.com  给封闭小区群众送菜#新冠肺炎已开始在日本流行##湖北一半以上确诊病例都用中医药治疗#L热门视...
# 78859      华为手机 畅享玩不停  【事发海口！一家族春节聚会，多人被感染新冠肺炎！】在今天下午举行的海口市新冠肺炎疫情防控工作...
# 9767     微博 weibo.com  新型冠状病毒肺炎袭来，家长别怕！四大措施要记牢，保护孩子健康 O新型冠状病毒肺炎袭来，家长别...
# 36949           专业版微博  #网上新闻发布厅#2月17日下午，云南省新冠肺炎疫情防控工作新闻发布会（第九场）在昆明海埂会...
# ...               ...                                                ...
# 22580  易峰宝贝的iPhone XR  武汉加油//@7569286525:中国加油//@3018282519:#勇战疫情中国要强#...
# 76837  HUAWEI P30 Pro                                               转发微博
# 64596       iPhone客户端  20191209，today是人生难得的hard模式。昨天带二宝去医院，咳嗽检查出肺炎要住院...
# 86182      三星A60黑瞳全视屏                          //@7402958913:米虫之 #武汉肺炎#
# 48685       iPhone客户端  我只有一个想法，能不能停了所有武汉官方的对外发布，宣传？让真正专业和负责的人来代替，别用兽医...
#
#               timestamp     user_id          weibo_id  \
# 49974  2020-02-16T09:59  4063283442  4472532743220345
# 40536  2020-02-16T15:52  2811732192  4472621489704474
# 78859  2020-02-13T14:57  6478101728  4471520476359222
# 9767   2020-02-21T20:36  1136802531  4474504963400103
# 36949  2020-02-17T15:54  3179581504  4472984477600781
# ...                 ...         ...               ...
# 22580  2020-02-04T19:43  7569286525  4468331006280270
# 76837  2020-02-02T11:50  6900332758  4467487384805440
# 64596  2019-12-09T15:00  5511917405  4447603750141560
# 86182  2020-02-04T12:48  9507633127  4468226702455210
# 48685  2020-02-09T23:46  8878472812  4470204056853543
#
#                                                     imgs  \
# 49974  [//ww1.sinaimg.cn/orj360/eaa12c11ly1gby0dc26n4...
# 40536                                                 []
# 78859  [//ww3.sinaimg.cn/orj360/c4f651a2gy1gbus562dxw...
# 9767   [//ww1.sinaimg.cn/orj360/0080M7eQgy1gc4awouaup...
# 36949  [//ww1.sinaimg.cn/orj360/6318a01dgy1gbzg9ll5p5...
# ...                                                  ...
# 22580                                                NaN
# 76837                                                NaN
# 64596                                                NaN
# 86182                                                NaN
# 48685                                                NaN
#
#                                           Repost_content  \
# 49974                                                NaN
# 40536                                                NaN
# 78859                                                NaN
# 9767                                                 NaN
# 36949                                                NaN
# ...                                                  ...
# 22580  #勇战疫情中国要强##蒙牛集团追加捐赠6.6亿，向白衣天使致敬#疫情无情人有情，在中粮集团领...
# 76837  武汉肺炎始发地华南海鲜市场，鲜为人知的照片看后真的触目惊心 O网页链接  #八旬老兵捐3万买...
# 64596                                                NaN
# 86182  呼吸衰竭走的，爸爸一定很辛苦吧，好好休息。🙏🏻 核酸检测为阳性，已确诊遗体接受表上仍然写的“...
# 48685  【#钟南山称新冠病毒和SARS是两回事#】#关注新冠肺炎#2月9日晚间，针对华中农业大学教授...
#
#                                              Repost_imgs  Repost_timestamp  \
# 49974                                                NaN               NaN
# 40536                                                NaN               NaN
# 78859                                                NaN               NaN
# 9767                                                 NaN               NaN
# 36949                                                NaN               NaN
# ...                                                  ...               ...
# 22580  [//ww1.sinaimg.cn/orj360/6289c7c4ly1gbgqjz107h...  2020-01-31T21:58
# 76837                                                NaN  2020-02-02T09:34
# 64596                                                NaN               NaN
# 86182                                                NaN  2020-02-03T11:37
# 48685  [//ww2.sinaimg.cn/orj360/6a5ce645gy1gbqkd9xhe4...  2020-02-09T23:25
#
#        Repost_username Repost_date Repost_state
# 49974              NaN         NaN          NaN
# 40536              NaN         NaN          NaN
# 78859              NaN         NaN          NaN
# 9767               NaN         NaN          NaN
# 36949              NaN         NaN          NaN
# ...                ...         ...          ...
# 22580     8.519423e+09         NaN          NaN
# 76837     6.451512e+09         NaN          NaN
# 64596              NaN         NaN          NaN
# 86182     9.681251e+09         NaN          NaN
# 48685     7.953156e+09         NaN          NaN
#
# [41000 rows x 12 columns]

# %%
# export dataframe 
df_total.to_csv("sampled.csv",sep = ",", header = True, encoding = "UTF-8")
