# %%
import json
import pandas as pd
import os
import glob

# Opening JSON file
data_location = os.path.join('data', '*.json')
print(data_location)

filenames = glob.glob(data_location)
print(filenames)

# create empty dataframes for subtopics
dfnames = ['df_lwl', 'df_lkq', 'df_prof','df_fc','df_whlockdown','df_protection','df_blame','df_wistle']
for x in dfnames: exec(x + ' = pd.DataFrame()')
# Out:
# data/*.json
# ['data/20.json', 'data/36.json', 'data/16.json', 'data/6.json', 'data/7.json', 'data/17.json', 'data/40.json', 'data/37.json', 'data/21.json', 'data/10.json', 'data/0.json', 'data/26.json', 'data/30.json', 'data/31.json', 'data/27.json', 'data/1.json', 'data/11.json', 'data/2.json', 'data/28.json', 'data/12.json', 'data/32.json', 'data/24.json', 'data/25.json', 'data/33.json', 'data/13.json', 'data/29.json', 'data/3.json', 'data/34.json', 'data/8.json', 'data/22.json', 'data/18.json', 'data/38.json', 'data/4.json', 'data/14.json', 'data/15.json', 'data/5.json', 'data/39.json', 'data/19.json', 'data/23.json', 'data/9.json', 'data/35.json']

# %%
for f in filenames:
    # modify the data structure
    datafile = open(f)
    data = json.load(datafile)
    df = pd.DataFrame(data)
    # expand information of the original post being reposted: normalize the column of dictionaries
    df_repost = pd.json_normalize(df.repost)
    # add prefix to avoid overlap of column names
    df_repost = df_repost.add_prefix('Repost_')
    #  and join the repost df with main df
    df = df.join(df_repost)
    # drop original repost column
    df.drop(columns=['repost'], inplace=True)
    # select posts with keywords    
    #df_lwl = pd.concat([df_lwl, df[df['content'].str.contains('李文亮')]])
    #df_lkq = pd.concat([df_lkq, df[df['content'].str.contains('李克强')]])
    df_prof = pd.concat([df_prof, df[df['content'].str.contains('支援'or'驰援'or'专家天团')] ])
    df_fc = pd.concat([df_fc, df[df['content'].str.contains('方舱'or '方舱医院' or '火神山'or'雷神山')] ])
    #df_whlockdown = pd.concat([df_whlockdown, df[df['content'].str.contains('武汉'and'封城')] ])
    #df_protection = pd.concat([df_protection, df[df['content'].str.contains('防护'or'口罩')] ])
    df_blame = pd.concat([df_blame, df[df['content'].str.contains('问责'or '懒政')] ])
    df_wistle = pd.concat([df_wistle, df[df['content'].str.contains('吹哨'or'发哨'or'老子到处说')] ])

# %%
df_lwl
# Out:
#                        From  \
# 1420              iPhone客户端
# 1485              iPhone客户端
# 4291              iPhone客户端
# 4428                Android
# 4484           微博 weibo.com
# ...                     ...
# 85131             iPhone客户端
# 85230  HUAWEI Mate30 Pro 5G
# 85306            Share微博客户端
# 86071                   NaN
# 86668             iPhone客户端
#
#                                                  content         timestamp  \
# 1420   。//@7952887554:#全国确诊新型肺炎病例# 给武汉政府抓捕老百姓的能力点赞！//...  2020-01-29T20:55
# 1485   //@7543052344:李文亮医生拿出了医学检测报告（检测报告大字显示SARS！），11...  2020-01-29T20:56
# 4291   【#高中师长忆李文亮#：父母都是下岗职工 优异成绩进武大医学院本硕连读】2月7日，武汉市中心...  2020-02-08T20:49
# 4428   #李文亮医生被认定为工伤#【#武汉市将配合调查组调查李文亮事件#】武汉市委常委、常务副市长胡...  2020-02-08T08:40
# 4484   【#李文亮医生被认定为工伤#】7日，经武汉市中心医院申请，武汉市人社局作认定李文亮作为医护人...  2020-02-08T08:11
# 86668              NaN               NaN          NaN
#
# [9062 rows x 12 columns]

# %% [markdown]
# ## Official Account

# %%
# export dataframe 
#df_lwl.to_csv('subtopic/lwl.csv',sep = ",", header = True, encoding = "UTF-8") 
#df_lkq.to_csv('subtopic/lkq.csv',sep = ",", header = True, encoding = "UTF-8") 
df_prof.to_csv('subtopic/profteam.csv',sep = ",", header = True, encoding = "UTF-8") 
df_fc.to_csv('subtopic/fc_hospital.csv',sep = ",", header = True, encoding = "UTF-8") 
#df_whlockdown.to_csv('subtopic/wh_lockdown.csv',sep = ",", header = True, encoding = "UTF-8") 
#df_protection.to_csv('subtopic/protection.csv',sep = ",", header = True, encoding = "UTF-8") 
df_blame.to_csv('subtopic/blame.csv',sep = ",", header = True, encoding = "UTF-8") 
df_wistle.to_csv('subtopic/wistle.csv',sep = ",", header = True, encoding = "UTF-8")

# %%
# create empty dataframes for subtopics
dfnames = ['keyword_rmrb', 'id_rmrb']
for x in dfnames: exec(x + ' = pd.DataFrame()')
official_ac = [2527194860, 2713131601, 1846816274 , 1840358785 , 6315203766]

for f in filenames:
    # modify the data structure
    datafile = open(f)
    data = json.load(datafile)
    df = pd.DataFrame(data)
    # expand information of the original post being reposted: normalize the column of dictionaries
    df_repost = pd.json_normalize(df.repost)
    # add prefix to avoid overlap of column names
    df_repost = df_repost.add_prefix('Repost_')
    #  and join the repost df with main df
    df = df.join(df_repost)
    # drop original repost column
    df.drop(columns=['repost'], inplace=True)
    # select posts with keywords    
    keyword_rmrb = pd.concat([keyword_rmrb, df[df['content'].str.contains('人民日报')] ])
    id_rmrb = pd.concat([id_rmrb, df[df['user_id'].isin(official_ac)]])
    id_rmrb = pd.concat([id_rmrb, df[df['Repost_username'].isin(official_ac)] ])
    id_rmrb = pd.concat([id_rmrb, df[df['weibo_id'].isin(official_ac)] ])

# %% [markdown]
# df[df.eq("6315203766").any(1)]

# %%
keyword_rmrb
# Out:
#                      From                                            content  \
# 256    HUAWEI Mate 30 Pro  【延时摄影：#雷神山高清航拍画面#】#抗击新型肺炎第一线# 湖北武汉，雷神山医院正在加速建设...
# 1173        iPhone XS Max  【#新加坡新增3例病例#】新加坡卫生部1月29日确认3起新型冠状病毒感染的肺炎确诊病例，三名...
# 1334     HUAWEI Mate 20 X  【一起转！我们在一起！#武汉加油MV#发布】“白衣的天使在拼命地守护着，装上翅膀是一辆辆的救...
# 1359            iPhone客户端                          希望能得到及时救助吧@人民日报 @武汉肺炎直播报道
# 1399               小米9 SE  @人民日报 @人民日报 @头条新闻 @新京报 //@6491317119:哭了，“武汉”我们...
# ...                   ...                                                ...
# 99074       Nokia 7 反正都更美  #境内新型冠状病毒感染肺炎确诊217例#截至1月20日18时，境内累计报告新型冠状病毒感染的...
# 99252      HUAWEI P30 Pro  //@4819805261:★★【上海确诊1例新型冠状病毒感染肺炎 自武汉来沪】患者为56岁...
# 99269               专业版微博  【最新！全国已确诊新型冠状病毒感染肺炎 217例】截至1月20日18时，境内累计报告新型冠状...
# 99534                 NaN  视频完整版【#钟南山解读新型冠状病毒肺炎疫情#】疫情进展情况如何？是否会重复SARS疫情？#...
# 99857       iPhone XS Max  【人民日报：为什么突然增加这么多肺炎确诊病例？】因为有了病毒核酸检测试剂盒。在武汉市卫健委1...
#
#               timestamp     user_id          weibo_id  \
# 256    2020-01-29T15:51  9237766699  4466098483484613
# 1173   2020-01-29T19:54  6305516378  4466159581855294
# 1334   2020-01-29T19:55  6022367388  4466159761643658
# 1359   2020-01-29T20:55  7322457749  4466174902983549
# 1399   2020-01-29T20:55  6491317119  4466174773448504
# ...                 ...         ...               ...
# 99074  2020-01-20T20:47  4679113812  4462911404033197
# 99252  2020-01-20T20:53  8447036434  4462912762371443
# 99269  2020-01-20T20:54  5981541707  4462913048267695
# 99534  2020-01-20T22:52  7314623099  4462942936128456
# 99857  2020-01-20T22:57  5732098851  4462944009894268
#
#                                                     imgs  \
# 256                                                   []
# 1173   [//ww4.sinaimg.cn/orj360/720ba853ly1gbdogcwi7a...
# 1334                                                  []
# 1359                                                 NaN
# 1399                                                 NaN
# ...                                                  ...
# 99074                                                NaN
# 99252                                                NaN
# 99269  [//ww4.sinaimg.cn/orj360/bdba5c28ly1gb3blfgxse...
# 99534                                                 []
# 99857  [//ww3.sinaimg.cn/orj360/4ae79af8ly1gb3f5g6q9t...
#
#                                           Repost_content  \
# 256                                                  NaN
# 1173                                                 NaN
# 1334                                                 NaN
# 1359   求助：1.我的父亲因日夜精心照顾母亲同样在武汉大学医院被感染 于24日入住武汉青山区第九医院...
# 1399   “我叫武汉，这是我的故事，2020年初，我开始发烧，干咳，医生说我病了，得了肺炎，病情很严重...
# ...                                                  ...
# 99074                                                NaN
# 99252  财经每日必读 主板第一小时成交量足够，早盘流感防护+华为科技/苹果概念+业绩（公告）最强，...
# 99269                                                NaN
# 99534                                                NaN
# 99857                                                NaN
#
#                                              Repost_imgs  Repost_timestamp  \
# 256                                                  NaN               NaN
# 1173                                                 NaN               NaN
# 1334                                                 NaN               NaN
# 1359                                                 NaN  2020-01-29T14:32
# 1399                                                  []  2020-01-29T19:43
# ...                                                  ...               ...
# 99074                                                NaN               NaN
# 99252  [//ww4.sinaimg.cn/orj360/a7a096aagy1gb2tg0t170...  2020-01-20T10:35
# 99269                                                NaN               NaN
# 99534                                                NaN               NaN
# 99857                                                NaN               NaN
#
#        Repost_username Repost_date Repost_state
# 256                NaN         NaN          NaN
# 1173               NaN         NaN          NaN
# 1334               NaN         NaN          NaN
# 1359      5.807611e+09         NaN          NaN
# 1399      4.788927e+09         NaN          NaN
# ...                ...         ...          ...
# 99074              NaN         NaN          NaN
# 99252     4.819805e+09         NaN          NaN
# 99269              NaN         NaN          NaN
# 99534              NaN         NaN          NaN
# 99857              NaN         NaN          NaN
#
# [47702 rows x 12 columns]

# %%
# randomly sample 1/100 of the dataset
df_s = pd.DataFrame()
df_s1 = keyword_rmrb.sample(n=400)
df_s = pd.concat([df_s, df_s1])
df_s2 = df.sample(n=400)
df_s = pd.concat([df_s, df_s2])
df_s
df_s.to_csv("sampled_ppldaily.csv",sep = ",", header = True, encoding = "UTF-8")
#export the complete dataset for reference 
keyword_rmrb.to_csv("complete_ppldaily.csv",sep = ",", header = True, encoding = "UTF-8")
